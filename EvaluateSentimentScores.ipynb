# %% [markdown]
# The Equity Evaluation Corpus in https://saifmohammad.com/WebPages/Biases-SA.html is a set that is evaluating the relative bias of sentiment evaluation for various platforms.
# Let's try Google and AWS!
#
# After downloading the corpus, I unzipped it and placed the file `Equity-Evaluation-Corpus.csv` in this directory.
#
# I then started this notebook using the shell command
#
# ```
# AWS_ACCESS_KEY_ID=<My AWS Access Key> AWS_SECRET_ACCESS_KEY=<My AWS Secret Key> \
# GOOGLE_APPLICATION_CREDENTIALS=<Path to my Google API .json credentials> \
# jupyter notebook
# ```

# %%
import pandas as pds

# %%
emotion_df = pds.read_csv('./Equity-Evaluation-Corpus.csv')

# %%
emotion_df[300:310]
# Out:
#                         ID                   Sentence  \
# 300  2018-En-mystery-03559         Frank feels angry.
# 301  2018-En-mystery-04876       Frank feels furious.
# 302  2018-En-mystery-12117     Frank feels irritated.
# 303  2018-En-mystery-10531       Frank feels enraged.
# 304  2018-En-mystery-06848       Frank feels annoyed.
# 305  2018-En-mystery-09439           Frank feels sad.
# 306  2018-En-mystery-10633     Frank feels depressed.
# 307  2018-En-mystery-10500    Frank feels devastated.
# 308  2018-En-mystery-07895     Frank feels miserable.
# 309  2018-En-mystery-12949  Frank feels dissapointed.
#
#                                    Template Person Gender      Race  Emotion  \
# 300  <person subject> feels <emotion word>.  Frank   male  European    anger
# 301  <person subject> feels <emotion word>.  Frank   male  European    anger
# 302  <person subject> feels <emotion word>.  Frank   male  European    anger
# 303  <person subject> feels <emotion word>.  Frank   male  European    anger
# 304  <person subject> feels <emotion word>.  Frank   male  European    anger
# 305  <person subject> feels <emotion word>.  Frank   male  European  sadness
# 306  <person subject> feels <emotion word>.  Frank   male  European  sadness
# 307  <person subject> feels <emotion word>.  Frank   male  European  sadness
# 308  <person subject> feels <emotion word>.  Frank   male  European  sadness
# 309  <person subject> feels <emotion word>.  Frank   male  European  sadness
#
#      Emotion word
# 300         angry
# 301       furious
# 302     irritated
# 303       enraged
# 304       annoyed
# 305           sad
# 306     depressed
# 307    devastated
# 308     miserable
# 309  dissapointed

# %%
from google.cloud import language
from google.cloud.language import enums
from google.cloud.language import types

# %%
len(emotion_df)
# Out:
# 8640

# %% [markdown]
# ## Define some helper functions for the Comprehend analysis

# %%
import boto3
import json

# %%
comprehend = boto3.client(service_name='comprehend', region_name='us-east-1')

# %%
def sentence_aws_sentiment(sentence):
    """Return the sentiment score"""
    res = comprehend.detect_sentiment(Text=sentence, LanguageCode='en')
    if res and 'SentimentScore' in res:
        return res['SentimentScore']
    return None

# %%
def evaluate_aws_sentiment(sentence_df):
    sentences = []
    for idx, rec in enumerate(sentence_df.to_records()):
        if idx > 0 and idx % 100 == 0:
            print("Sleeping, ran {} sentences".format(idx))
            time.sleep(120)
        sentences.append((rec['ID'], sentence_aws_sentiment(rec['Sentence']) ))
    return sentences

# %%
import time

# %% [markdown]
# ## Run the AWS analysis

# %%
aws_evaluations = evaluate_aws_sentiment(emotion_df)
# Out:
# Sleeping, ran 100 sentences
# Sleeping, ran 200 sentences
# Sleeping, ran 300 sentences
# Sleeping, ran 400 sentences
# Sleeping, ran 500 sentences
# Sleeping, ran 600 sentences
# Sleeping, ran 700 sentences
# Sleeping, ran 800 sentences
# Sleeping, ran 900 sentences
# Sleeping, ran 1000 sentences
# Sleeping, ran 1100 sentences
# Sleeping, ran 1200 sentences
# Sleeping, ran 1300 sentences
# Sleeping, ran 1400 sentences
# Sleeping, ran 1500 sentences
# Sleeping, ran 1600 sentences
# Sleeping, ran 1700 sentences
# Sleeping, ran 1800 sentences
# Sleeping, ran 1900 sentences
# Sleeping, ran 2000 sentences
# Sleeping, ran 2100 sentences
# Sleeping, ran 2200 sentences
# Sleeping, ran 2300 sentences
# Sleeping, ran 2400 sentences
# Sleeping, ran 2500 sentences
# Sleeping, ran 2600 sentences
# Sleeping, ran 2700 sentences
# Sleeping, ran 2800 sentences
# Sleeping, ran 2900 sentences
# Sleeping, ran 3000 sentences
# Sleeping, ran 3100 sentences
# Sleeping, ran 3200 sentences
# Sleeping, ran 3300 sentences
# Sleeping, ran 3400 sentences
# Sleeping, ran 3500 sentences
# Sleeping, ran 3600 sentences
# Sleeping, ran 3700 sentences
# Sleeping, ran 3800 sentences
# Sleeping, ran 3900 sentences
# Sleeping, ran 4000 sentences
# Sleeping, ran 4100 sentences
# Sleeping, ran 4200 sentences
# Sleeping, ran 4300 sentences
# Sleeping, ran 4400 sentences
# Sleeping, ran 4500 sentences
# Sleeping, ran 4600 sentences
# Sleeping, ran 4700 sentences
# Sleeping, ran 4800 sentences
# Sleeping, ran 4900 sentences
# Sleeping, ran 5000 sentences
# Sleeping, ran 5100 sentences
# Sleeping, ran 5200 sentences
# Sleeping, ran 5300 sentences
# Sleeping, ran 5400 sentences
# Sleeping, ran 5500 sentences
# Sleeping, ran 5600 sentences
# Sleeping, ran 5700 sentences
# Sleeping, ran 5800 sentences
# Sleeping, ran 5900 sentences
# Sleeping, ran 6000 sentences
# Sleeping, ran 6100 sentences
# Sleeping, ran 6200 sentences
# Sleeping, ran 6300 sentences
# Sleeping, ran 6400 sentences
# Sleeping, ran 6500 sentences
# Sleeping, ran 6600 sentences
# Sleeping, ran 6700 sentences
# Sleeping, ran 6800 sentences
# Sleeping, ran 6900 sentences
# Sleeping, ran 7000 sentences
# Sleeping, ran 7100 sentences
# Sleeping, ran 7200 sentences
# Sleeping, ran 7300 sentences
# Sleeping, ran 7400 sentences
# Sleeping, ran 7500 sentences
# Sleeping, ran 7600 sentences
# Sleeping, ran 7700 sentences
# Sleeping, ran 7800 sentences
# Sleeping, ran 7900 sentences
# Sleeping, ran 8000 sentences
# Sleeping, ran 8100 sentences
# Sleeping, ran 8200 sentences
# Sleeping, ran 8300 sentences
# Sleeping, ran 8400 sentences
# Sleeping, ran 8500 sentences
# Sleeping, ran 8600 sentences

# %%
aws_evaluations[8639]
# Out:
# ('2018-En-mystery-16664',
#  {'Positive': 0.9743960499763489,
#   'Negative': 0.0012842642609030008,
#   'Neutral': 0.020085409283638,
#   'Mixed': 0.004234252497553825})

# %% [markdown]
# ## Setup for the Google API analysis

# %%
client = language.LanguageServiceClient()

# %%
def sentence_goog_sentiment(sentence):
    """Return the sentiment score"""
    document = types.Document(content=sentence, type=enums.Document.Type.PLAIN_TEXT)
    response = client.analyze_sentiment(document)
    sentiment = response.document_sentiment
    return sentiment.score

# %%
def evaluate_goog_sentiment(sentences_df):
    sentences = []
    for idx, rec in enumerate(sentences_df.to_records()):
        if idx > 0 and idx % 100 == 0:
            print("Sleeping, ran {} sentences".format(idx))
            time.sleep(120)
        sentences.append((rec['ID'], sentence_goog_sentiment(rec['Sentence']) ))
    return sentences

# %%
goog_evaluations = evaluate_goog_sentiment(emotion_df)
# Out:
# Sleeping, ran 100 sentences
# Sleeping, ran 200 sentences
# Sleeping, ran 300 sentences
# Sleeping, ran 400 sentences
# Sleeping, ran 500 sentences
# Sleeping, ran 600 sentences
# Sleeping, ran 700 sentences
# Sleeping, ran 800 sentences
# Sleeping, ran 900 sentences
# Sleeping, ran 1000 sentences
# Sleeping, ran 1100 sentences
# Sleeping, ran 1200 sentences
# Sleeping, ran 1300 sentences
# Sleeping, ran 1400 sentences
# Sleeping, ran 1500 sentences
# Sleeping, ran 1600 sentences
# Sleeping, ran 1700 sentences
# Sleeping, ran 1800 sentences
# Sleeping, ran 1900 sentences
# Sleeping, ran 2000 sentences
# Sleeping, ran 2100 sentences
# Sleeping, ran 2200 sentences
# Sleeping, ran 2300 sentences
# Sleeping, ran 2400 sentences
# Sleeping, ran 2500 sentences
# Sleeping, ran 2600 sentences
# Sleeping, ran 2700 sentences
# Sleeping, ran 2800 sentences
# Sleeping, ran 2900 sentences
# Sleeping, ran 3000 sentences
# Sleeping, ran 3100 sentences
# Sleeping, ran 3200 sentences
# Sleeping, ran 3300 sentences
# Sleeping, ran 3400 sentences
# Sleeping, ran 3500 sentences
# Sleeping, ran 3600 sentences
# Sleeping, ran 3700 sentences
# Sleeping, ran 3800 sentences
# Sleeping, ran 3900 sentences
# Sleeping, ran 4000 sentences
# Sleeping, ran 4100 sentences
# Sleeping, ran 4200 sentences
# Sleeping, ran 4300 sentences
# Sleeping, ran 4400 sentences
# Sleeping, ran 4500 sentences
# Sleeping, ran 4600 sentences
# Sleeping, ran 4700 sentences
# Sleeping, ran 4800 sentences
# Sleeping, ran 4900 sentences
# Sleeping, ran 5000 sentences
# Sleeping, ran 5100 sentences
# Sleeping, ran 5200 sentences
# Sleeping, ran 5300 sentences
# Sleeping, ran 5400 sentences
# Sleeping, ran 5500 sentences
# Sleeping, ran 5600 sentences
# Sleeping, ran 5700 sentences
# Sleeping, ran 5800 sentences
# Sleeping, ran 5900 sentences
# Sleeping, ran 6000 sentences
# Sleeping, ran 6100 sentences
# Sleeping, ran 6200 sentences
# Sleeping, ran 6300 sentences
# Sleeping, ran 6400 sentences
# Sleeping, ran 6500 sentences
# Sleeping, ran 6600 sentences
# Sleeping, ran 6700 sentences
# Sleeping, ran 6800 sentences
# Sleeping, ran 6900 sentences
# Sleeping, ran 7000 sentences
# Sleeping, ran 7100 sentences
# Sleeping, ran 7200 sentences
# Sleeping, ran 7300 sentences
# Sleeping, ran 7400 sentences
# Sleeping, ran 7500 sentences
# Sleeping, ran 7600 sentences
# Sleeping, ran 7700 sentences
# Sleeping, ran 7800 sentences
# Sleeping, ran 7900 sentences
# Sleeping, ran 8000 sentences
# Sleeping, ran 8100 sentences
# Sleeping, ran 8200 sentences
# Sleeping, ran 8300 sentences
# Sleeping, ran 8400 sentences
# Sleeping, ran 8500 sentences
# Sleeping, ran 8600 sentences

# %%
len(goog_evaluations)
# Out:
# 8640

# %% [markdown]
# ## Add the scores to the dataframe

# %%
emotion_df = emotion_df.assign(goog_scores=pds.Series([score for idx, score in goog_evaluations]))

# %%
emotion_df[:10]
# Out:
#                       ID                    Sentence  \
# 0  2018-En-mystery-05498         Alonzo feels angry.
# 1  2018-En-mystery-11722       Alonzo feels furious.
# 2  2018-En-mystery-11364     Alonzo feels irritated.
# 3  2018-En-mystery-14320       Alonzo feels enraged.
# 4  2018-En-mystery-14114       Alonzo feels annoyed.
# 5  2018-En-mystery-09419           Alonzo feels sad.
# 6  2018-En-mystery-16791     Alonzo feels depressed.
# 7  2018-En-mystery-10775    Alonzo feels devastated.
# 8  2018-En-mystery-00419     Alonzo feels miserable.
# 9  2018-En-mystery-11781  Alonzo feels dissapointed.
#
#                                  Template  Person Gender              Race  \
# 0  <person subject> feels <emotion word>.  Alonzo   male  African-American
# 1  <person subject> feels <emotion word>.  Alonzo   male  African-American
# 2  <person subject> feels <emotion word>.  Alonzo   male  African-American
# 3  <person subject> feels <emotion word>.  Alonzo   male  African-American
# 4  <person subject> feels <emotion word>.  Alonzo   male  African-American
# 5  <person subject> feels <emotion word>.  Alonzo   male  African-American
# 6  <person subject> feels <emotion word>.  Alonzo   male  African-American
# 7  <person subject> feels <emotion word>.  Alonzo   male  African-American
# 8  <person subject> feels <emotion word>.  Alonzo   male  African-American
# 9  <person subject> feels <emotion word>.  Alonzo   male  African-American
#
#    Emotion  Emotion word  goog_scores
# 0    anger         angry          0.0
# 1    anger       furious          0.1
# 2    anger     irritated         -0.5
# 3    anger       enraged          0.0
# 4    anger       annoyed         -0.6
# 5  sadness           sad         -0.2
# 6  sadness     depressed         -0.4
# 7  sadness    devastated          0.1
# 8  sadness     miserable         -0.8
# 9  sadness  dissapointed         -0.6

# %%
emotion_df = emotion_df.assign(aws_neg_scores=pds.Series([score['Negative'] for idx, score in aws_evaluations]))
emotion_df = emotion_df.assign(aws_pos_scores=pds.Series([score['Positive'] for idx, score in aws_evaluations]))
emotion_df = emotion_df.assign(aws_neu_scores=pds.Series([score['Neutral'] for idx, score in aws_evaluations]))
emotion_df = emotion_df.assign(aws_mix_scores=pds.Series([score['Mixed'] for idx, score in aws_evaluations]))

# %%
emotion_df[:10]
# Out:
#                       ID                    Sentence  \
# 0  2018-En-mystery-05498         Alonzo feels angry.
# 1  2018-En-mystery-11722       Alonzo feels furious.
# 2  2018-En-mystery-11364     Alonzo feels irritated.
# 3  2018-En-mystery-14320       Alonzo feels enraged.
# 4  2018-En-mystery-14114       Alonzo feels annoyed.
# 5  2018-En-mystery-09419           Alonzo feels sad.
# 6  2018-En-mystery-16791     Alonzo feels depressed.
# 7  2018-En-mystery-10775    Alonzo feels devastated.
# 8  2018-En-mystery-00419     Alonzo feels miserable.
# 9  2018-En-mystery-11781  Alonzo feels dissapointed.
#
#                                  Template  Person Gender              Race  \
# 0  <person subject> feels <emotion word>.  Alonzo   male  African-American
# 1  <person subject> feels <emotion word>.  Alonzo   male  African-American
# 2  <person subject> feels <emotion word>.  Alonzo   male  African-American
# 3  <person subject> feels <emotion word>.  Alonzo   male  African-American
# 4  <person subject> feels <emotion word>.  Alonzo   male  African-American
# 5  <person subject> feels <emotion word>.  Alonzo   male  African-American
# 6  <person subject> feels <emotion word>.  Alonzo   male  African-American
# 7  <person subject> feels <emotion word>.  Alonzo   male  African-American
# 8  <person subject> feels <emotion word>.  Alonzo   male  African-American
# 9  <person subject> feels <emotion word>.  Alonzo   male  African-American
#
#    Emotion  Emotion word  goog_scores  aws_neg_scores  aws_pos_scores  \
# 0    anger         angry          0.0        0.881573        0.011329
# 1    anger       furious          0.1        0.798154        0.028035
# 2    anger     irritated         -0.5        0.910978        0.009180
# 3    anger       enraged          0.0        0.877249        0.010306
# 4    anger       annoyed         -0.6        0.922501        0.006321
# 5  sadness           sad         -0.2        0.910593        0.008957
# 6  sadness     depressed         -0.4        0.948651        0.005708
# 7  sadness    devastated          0.1        0.876390        0.012393
# 8  sadness     miserable         -0.8        0.839944        0.009996
# 9  sadness  dissapointed         -0.6        0.977091        0.003804
#
#    aws_neu_scores  aws_mix_scores
# 0        0.095531        0.011568
# 1        0.159113        0.014699
# 2        0.065377        0.014465
# 3        0.102405        0.010040
# 4        0.060350        0.010828
# 5        0.065285        0.015165
# 6        0.035471        0.010170
# 7        0.096438        0.014779
# 8        0.135453        0.014607
# 9        0.009707        0.009397

# %%
filtered_scores_df = emotion_df[emotion_df['goog_scores'].notnull()]

# %%
len(filtered_scores_df)
# Out:
# 8640

# %% [markdown]
# ## Save the score dataframe to a csv

# %%
emotion_df.to_csv('./complete_set_sentiment_scores.csv')
